# %%
import os
import pickle
import time

import numpy as np
import xgboost
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight

from src.mymetrics import MyMetrics
from src.ppi import PPI


def get_project_rootpath():
    """
    获取项目根目录。此函数的能力体现在，不论当前module被import到任何位置，都可以正确获取项目根目录
    :return:
    """
    path = os.path.realpath(os.curdir)
    while True:
        for subpath in os.listdir(path):
            # PyCharm项目中，'.idea'是必然存在的，且名称唯一
            if '.idea' in subpath:
                return path
        path = os.path.dirname(path)


os.chdir(get_project_rootpath())
EMB_ROOT_PATH = 'data/emb/'
PPI_PATH = 'data/network/PPI-Network.txt'
GENECOUNT_PATH = 'data/genecount.xls'
DEEPWALK_EMB_ROOT_PATH = os.path.join(EMB_ROOT_PATH, 'deepwalk')
ENCODED_EMB_ROOT_PATH = os.path.join(EMB_ROOT_PATH, 'encoded')

ppi = PPI(ppi_network_path=PPI_PATH, gene_count_path=GENECOUNT_PATH, k=6)

# %%
def dataloader(file_name, positive_gene: set, risklevel: dict):
    data = file_name.strip('.emb').split('_')
    param = {i[0]: i[1:] for i in data[1:4]}

    # 训练特征和label
    file_path = os.path.join(ENCODED_EMB_ROOT_PATH, file_name)
    with open(file_path, 'r') as f:
        data = [line.strip().split() for line in f.readlines()[1:]]
    X = [line[1:] for line in data]
    target = [1 if int(line[0]) in positive_gene else 0 for line in data]
    X = np.asarray(X, dtype=float)
    target = np.asarray(target, dtype=int)

    # 权重
    class_weight = compute_class_weight(class_weight='balanced', classes=[0, 1], y=target)
    sample_weight = [risklevel[int(line[0])] * class_weight[1]
                     if int(line[0]) in positive_gene else class_weight[0] for line in data]
    return param, X, target, sample_weight

# %%
ENCODED_EMB_ROOT_PATH = os.path.join(EMB_ROOT_PATH, 'encoded')
datasets = os.listdir(ENCODED_EMB_ROOT_PATH)
models_encoded = {}
result_acc = {}
result_f1 = {}
result_auc = {}
result_aupr = {}
step = 1

xgb_params = {
    'objective': 'binary:logistic',
    'eval_metric': 'auc',
    'n_estimators': 1550,
    'learning_rate': 0.01,
    'max_depth': 6,
    'min_child_weight': 5,
    'gamma': 0.5,
    'subsample': 0.8,
    'colsample_bytree': 0.9,
    'reg_alpha': 0.1,
    'reg_lambda': 1,
    'seed': 420
}

classifier = xgboost.XGBClassifier(**xgb_params)

for dataset in datasets:
    start_time = time.time()
    params, X, y, weight = dataloader(dataset, ppi.positive_id, ppi.risk_level)
    X_train, X_test, y_train, y_test, weight_train, weights_test = train_test_split(X, y,
                                                                                    weight,
                                                                                    test_size=0.3,
                                                                                    random_state=420)

    classifier.fit(X_train, y_train)
    y_pred = classifier.predict(X_test)
    y_score = classifier.predict_proba(X_test)[:, 1]

    metric = MyMetrics(y_test, y_pred)
    acc, f1, auc, aupr = metric.evaluate(y_test, y_pred, y_score)
    result_acc[(params['d'], params['l'], params['n'])] = acc
    result_f1[(params['d'], params['l'], params['n'])] = f1
    result_auc[(params['d'], params['l'], params['n'])] = auc
    result_aupr[(params['d'], params['l'], params['n'])] = aupr
    # save the trained model
    model_name = f"{params['d']}_{params['l']}_{params['n']}_deepwalk"
    models_encoded[model_name] = {'clf': classifier, 'f1': f1, 'aur': auc, 'acc': acc, 'aupr': aupr}

    end_time = time.time()
    time_taken = end_time - start_time
    print(f"Time taken for iteration {step}: {time_taken} seconds")
    print(f"params: dim:{params['d']}, length:{params['l']}, num:{params['n']}")
    print(f"f1:{f1:.4f}, auc:{auc:.4f}, acc:{acc:.4f}, aupr:{aupr:.4f}\n")
    step += 1

# save all models in a file
with open("model/deepwalk_encoded_all_xgb_models.pkl", "wb") as f:
    pickle.dump(models_encoded, f)
# Out:
# Time taken for iteration 1: 70.66596388816833 seconds
# params: dim:128, length:20, num:80
# f1:0.7161, auc:0.7689, acc:0.6936, aupr:0.7677
#
# Time taken for iteration 2: 69.92443704605103 seconds
# params: dim:256, length:20, num:20
# f1:0.7059, auc:0.7592, acc:0.6849, aupr:0.7611
#
# Time taken for iteration 3: 68.70206809043884 seconds
# params: dim:128, length:80, num:40
# f1:0.7225, auc:0.7774, acc:0.7022, aupr:0.7763
#
# Time taken for iteration 4: 68.87228107452393 seconds
# params: dim:512, length:40, num:40
# f1:0.7237, auc:0.7754, acc:0.7033, aupr:0.7719
#
# Time taken for iteration 5: 67.66861009597778 seconds
# params: dim:64, length:40, num:80
# f1:0.7295, auc:0.7873, acc:0.7104, aupr:0.7890
#
# Time taken for iteration 6: 70.11348295211792 seconds
# params: dim:128, length:80, num:20
# f1:0.7245, auc:0.7793, acc:0.7052, aupr:0.7772
#
# Time taken for iteration 7: 67.70546007156372 seconds
# params: dim:256, length:80, num:80
# f1:0.7251, auc:0.7779, acc:0.7016, aupr:0.7792
#
# Time taken for iteration 8: 67.37105798721313 seconds
# params: dim:256, length:20, num:40
# f1:0.7069, auc:0.7611, acc:0.6866, aupr:0.7621
#
# Time taken for iteration 9: 68.1554172039032 seconds
# params: dim:512, length:40, num:20
# f1:0.7194, auc:0.7747, acc:0.7001, aupr:0.7738
#
# Time taken for iteration 10: 68.5494978427887 seconds
# params: dim:512, length:40, num:80
# f1:0.7340, auc:0.7840, acc:0.7118, aupr:0.7783
#
# Time taken for iteration 11: 69.42518305778503 seconds
# params: dim:64, length:40, num:40
# f1:0.7255, auc:0.7851, acc:0.7059, aupr:0.7887
#
# Time taken for iteration 12: 72.32489919662476 seconds
# params: dim:128, length:20, num:40
# f1:0.7099, auc:0.7681, acc:0.6911, aupr:0.7661
#
# Time taken for iteration 13: 73.62850499153137 seconds
# params: dim:256, length:80, num:20
# f1:0.7222, auc:0.7750, acc:0.7002, aupr:0.7730
#
# Time taken for iteration 14: 72.95815396308899 seconds
# params: dim:128, length:80, num:80
# f1:0.7305, auc:0.7839, acc:0.7098, aupr:0.7802
#
# Time taken for iteration 15: 71.44153499603271 seconds
# params: dim:64, length:40, num:20
# f1:0.7315, auc:0.7896, acc:0.7143, aupr:0.7903
#
# Time taken for iteration 16: 73.11405801773071 seconds
# params: dim:256, length:80, num:40
# f1:0.7218, auc:0.7733, acc:0.6987, aupr:0.7729
#
# Time taken for iteration 17: 69.43319082260132 seconds
# params: dim:256, length:20, num:80
# f1:0.7205, auc:0.7736, acc:0.6987, aupr:0.7678
#
# Time taken for iteration 18: 69.94379901885986 seconds
# params: dim:128, length:20, num:20
# f1:0.7086, auc:0.7605, acc:0.6895, aupr:0.7643
#
# Time taken for iteration 19: 68.00858330726624 seconds
# params: dim:256, length:40, num:40
# f1:0.7143, auc:0.7709, acc:0.6905, aupr:0.7720
#
# Time taken for iteration 20: 67.81705713272095 seconds
# params: dim:512, length:20, num:20
# f1:0.7070, auc:0.7600, acc:0.6869, aupr:0.7616
#
# Time taken for iteration 21: 68.79731011390686 seconds
# params: dim:64, length:80, num:20
# f1:0.7240, auc:0.7876, acc:0.7062, aupr:0.7898
#
# Time taken for iteration 22: 68.1777892112732 seconds
# params: dim:256, length:40, num:20
# f1:0.7204, auc:0.7753, acc:0.7008, aupr:0.7732
#
# Time taken for iteration 23: 90.53000235557556 seconds
# params: dim:128, length:40, num:80
# f1:0.7151, auc:0.7708, acc:0.6957, aupr:0.7665
#
# Time taken for iteration 24: 73.81686019897461 seconds
# params: dim:64, length:80, num:40
# f1:0.7300, auc:0.7883, acc:0.7081, aupr:0.7913
#
# Time taken for iteration 25: 71.58981990814209 seconds
# params: dim:512, length:20, num:40
# f1:0.7183, auc:0.7732, acc:0.7004, aupr:0.7744
#
# Time taken for iteration 26: 68.39007306098938 seconds
# params: dim:64, length:20, num:80
# f1:0.7243, auc:0.7830, acc:0.7047, aupr:0.7865
#
# Time taken for iteration 27: 70.86229300498962 seconds
# params: dim:512, length:80, num:80
# f1:0.7343, auc:0.7839, acc:0.7126, aupr:0.7800
#
# Time taken for iteration 28: 65.78593683242798 seconds
# params: dim:512, length:80, num:20
# f1:0.7232, auc:0.7767, acc:0.7010, aupr:0.7753
#
# Time taken for iteration 29: 65.39341998100281 seconds
# params: dim:64, length:20, num:20
# f1:0.7208, auc:0.7773, acc:0.7022, aupr:0.7828
#
# Time taken for iteration 30: 65.40075516700745 seconds
# params: dim:128, length:40, num:20
# f1:0.7188, auc:0.7725, acc:0.6981, aupr:0.7688
#
# Time taken for iteration 31: 65.64596676826477 seconds
# params: dim:256, length:40, num:80
# f1:0.7163, auc:0.7734, acc:0.6954, aupr:0.7715
#
# Time taken for iteration 32: 63.212538957595825 seconds
# params: dim:64, length:80, num:80
# f1:0.7303, auc:0.7926, acc:0.7110, aupr:0.7957
#
# Time taken for iteration 33: 62.31747078895569 seconds
# params: dim:512, length:20, num:80
# f1:0.7251, auc:0.7779, acc:0.7032, aupr:0.7748
#
# Time taken for iteration 34: 62.49344301223755 seconds
# params: dim:64, length:20, num:40
# f1:0.7296, auc:0.7859, acc:0.7104, aupr:0.7878
#
# Time taken for iteration 35: 62.55949020385742 seconds
# params: dim:512, length:80, num:40
# f1:0.7362, auc:0.7854, acc:0.7155, aupr:0.7812
#
# Time taken for iteration 36: 62.37459397315979 seconds
# params: dim:128, length:40, num:40
# f1:0.7130, auc:0.7697, acc:0.6912, aupr:0.7676

# %%
def observe_param_effect(result_dict, param):
    def get_param_values(p):
        values = set()
        for key in result_dict.keys():
            values.add(key[p])
        return list(values)

    def get_avg_param(k):
        k_items = list(filter(lambda x: x[0][0] == k, result_dict.items()))
        k_values = [x[1] for x in k_items]

        avg_k = sum(k_values) / len(k_values)
        return avg_k

    param_map = {
        'dim': 0,
        'length': 1,
        'num': 2
    }
    return {int(k): get_avg_param(k) for k in get_param_values(param_map[param])}


observe_param_effect(result_aupr, 'dim')
# Out:
# {128: 0.7705202330927562,
#  512: 0.7745656052637147,
#  64: 0.789101162643912,
#  256: 0.770303549949294}

# %%
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
# %matplotlib notebook

def log_tick_formatter(val, pos=None):
    return f"{int(2 ** val)}"


def log_divide_tick_formatter(val, pos=None):
    return f"{int(10 * (2 ** val))}"


def log2_divide_by_10(l):
    divide_list = list(map(lambda x: x / 10, l))
    log_list = list(map(lambda x: np.log2(x), divide_list))
    return log_list


def plot_3d_params_impact(result_params: dict):
    x = []
    y = []
    z = []
    c = []
    for k, v in result_params.items():
        x.append(int(k[0]))
        y.append(int(k[1]))
        z.append(int(k[2]))
        c.append(v)

    x = list(map(lambda x: np.log2(x), x))
    y = log2_divide_by_10(y)
    z = log2_divide_by_10(z)

    # Creating figure
    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(111, projection='3d')

    # Add x, y, z gridlines
    ax.grid(visible=True, color='grey',
            linestyle='-.', linewidth=0.3,
            alpha=0.2)

    # Creating color map
    my_cmap = plt.get_cmap('hot')

    # Creating plot
    sctt = ax.scatter3D(x, y, z, alpha=0.8, c=c, cmap=my_cmap)

    plt.title("simple 3D scatter plot")

    ax.set_xlabel('dim', fontweight='bold')
    ax.set_ylabel('length', fontweight='bold')
    ax.set_zlabel('num', fontweight='bold')

    ax.xaxis.set_major_locator(ticker.MaxNLocator(4))
    ax.yaxis.set_major_locator(ticker.MaxNLocator(3))
    ax.zaxis.set_major_locator(ticker.MaxNLocator(3))

    # Set x, y, z axis tick formatters
    ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: log_tick_formatter(x)))
    ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: log_divide_tick_formatter(x)))
    ax.zaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: log_divide_tick_formatter(x)))

    fig.colorbar(sctt, ax=ax, shrink=0.5, aspect=5)
    plt.show()


plot_3d_params_impact(result_acc)
# Out:
# <div id='e10edfae-af08-4229-9bda-bf7b9b0ac749'></div>

# %%
plot_3d_params_impact(result_auc)
# Out:
# <div id='4f3daba8-6cbc-4e47-a685-af5c1dd53564'></div>

# %%
plot_3d_params_impact(result_f1)
# Out:
# <div id='b9c337db-d828-4114-aca5-dbeb02e7f859'></div>

# %%
plot_3d_params_impact(result_aupr)
# Out:
# <div id='19a2008c-5edc-4760-a786-dd07909566b0'></div>

# %%
import dill
with open('log/xgboost_result.pkl','wb') as f:
    dill.dump(result_acc,f)
    dill.dump(result_aupr,f)
    dill.dump(result_f1,f)
    dill.dump(result_auc,f)

# %%
# datasets = os.listdir(DEEPWALK_EMB_ROOT_PATH)
#
# models = {}
# result_acc = {}
# result_f1 = {}
# result_auc = {}
# result_aupr = {}
# step = 1
#
# xgb_params = {
#     'objective': 'binary:logistic',
#     'eval_metric': 'auc',
#     'n_estimators': 1550,
#     'learning_rate': 0.01,
#     'max_depth': 6,
#     'min_child_weight': 5,
#     'gamma': 0.5,
#     'subsample': 0.8,
#     'colsample_bytree': 0.9,
#     'reg_alpha': 0.1,
#     'reg_lambda': 1,
#     'seed': 420
# }
# classifier = xgboost.XGBClassifier(**xgb_params)
#
# for dataset in datasets:
#     start_time = time.time()
#     params, X, y, weight = dataloader(dataset, ppi.positive_id, ppi.risk_level)
#     X_train, X_test, y_train, y_test, weight_train, weights_test = train_test_split(X, y,
#                                                                                     weight,
#                                                                                     test_size=0.3,
#                                                                                     random_state=420)
#
#     classifier.fit(X_train, y_train)
#     y_pred = classifier.predict(X_test)
#     y_score = classifier.predict_proba(X_test)[:, 1]
#
#     metric = MyMetrics(y_test, y_pred)
#     acc, f1, auc, aupr = metric.evaluate(y_test, y_pred, y_score)
#     result_acc[(params['d'], params['l'], params['n'])] = acc
#     result_f1[(params['d'], params['l'], params['n'])] = f1
#     result_auc[(params['d'], params['l'], params['n'])] = auc
#     result_aupr[(params['d'], params['l'], params['n'])] = aupr
#     # save the trained model
#     model_name = f"{params['d']}_{params['l']}_{params['n']}_deepwalk"
#     models[model_name] = {'clf': classifier, 'f1': f1, 'aur': auc, 'acc': acc, 'aupr': aupr}
#     end_time = time.time()
#     time_taken = end_time - start_time
#
#     print(f"Time taken for iteration {step}: {time_taken} seconds")
#     print(f"iteration {step} params: dim:{params['d']}, length:{params['l']}, num:{params['n']}")
#     print(f"f1:{f1:.4f}, auc:{auc:.4f}, acc:{acc:.4f}, aupr:{aupr:.4f}\n")
#     step += 1
#
# # save all models in a file
# with open("model/deepwalk_all_xgb_models.pkl", "wb") as f:
#     pickle.dump(models, f)
# Out:
# Time taken for iteration 1: 83.20530414581299 seconds
# iteration 1 params: dim:64, length:40, num:20
# f1:0.7315, auc:0.7896, acc:0.7143, aupr:0.7903
#
# Time taken for iteration 2: 154.36654114723206 seconds
# iteration 2 params: dim:128, length:80, num:20
# f1:0.7276, auc:0.7876, acc:0.7106, aupr:0.7884
#
# Time taken for iteration 3: 146.87323784828186 seconds
# iteration 3 params: dim:128, length:20, num:20
# f1:0.7132, auc:0.7698, acc:0.6967, aupr:0.7777
#
# Time taken for iteration 4: 78.93629693984985 seconds
# iteration 4 params: dim:64, length:20, num:80
# f1:0.7243, auc:0.7830, acc:0.7047, aupr:0.7865
#
# Time taken for iteration 5: 145.19131898880005 seconds
# iteration 5 params: dim:128, length:40, num:40
# f1:0.7234, auc:0.7840, acc:0.7036, aupr:0.7872
#
# Time taken for iteration 6: 81.8835711479187 seconds
# iteration 6 params: dim:64, length:80, num:40
# f1:0.7300, auc:0.7883, acc:0.7081, aupr:0.7913
#
# Time taken for iteration 7: 148.77970385551453 seconds
# iteration 7 params: dim:128, length:40, num:80
# f1:0.7263, auc:0.7849, acc:0.7070, aupr:0.7879
#
# Time taken for iteration 8: 79.25919198989868 seconds
# iteration 8 params: dim:64, length:20, num:40
# f1:0.7296, auc:0.7859, acc:0.7104, aupr:0.7878
#
# Time taken for iteration 9: 80.03548121452332 seconds
# iteration 9 params: dim:64, length:80, num:80
# f1:0.7303, auc:0.7926, acc:0.7110, aupr:0.7957
#
# Time taken for iteration 10: 79.13281297683716 seconds
# iteration 10 params: dim:64, length:40, num:80
# f1:0.7295, auc:0.7873, acc:0.7104, aupr:0.7890
#
# Time taken for iteration 11: 146.27061915397644 seconds
# iteration 11 params: dim:128, length:20, num:40
# f1:0.7231, auc:0.7804, acc:0.7064, aupr:0.7856
#
# Time taken for iteration 12: 145.97884392738342 seconds
# iteration 12 params: dim:128, length:80, num:80
# f1:0.7308, auc:0.7945, acc:0.7118, aupr:0.7992
#
# Time taken for iteration 13: 136.71971201896667 seconds
# iteration 13 params: dim:128, length:20, num:80
# f1:0.7211, auc:0.7822, acc:0.7050, aupr:0.7867
#
# Time taken for iteration 14: 62.7755970954895 seconds
# iteration 14 params: dim:64, length:40, num:40
# f1:0.7255, auc:0.7851, acc:0.7059, aupr:0.7887
#
# Time taken for iteration 15: 117.68411326408386 seconds
# iteration 15 params: dim:128, length:80, num:40
# f1:0.7343, auc:0.7892, acc:0.7155, aupr:0.7927
#
# Time taken for iteration 16: 63.30338501930237 seconds
# iteration 16 params: dim:64, length:20, num:20
# f1:0.7208, auc:0.7773, acc:0.7022, aupr:0.7828
#
# Time taken for iteration 17: 117.55951404571533 seconds
# iteration 17 params: dim:128, length:40, num:20
# f1:0.7279, auc:0.7864, acc:0.7118, aupr:0.7911
#
# Time taken for iteration 18: 63.01248097419739 seconds
# iteration 18 params: dim:64, length:80, num:20
# f1:0.7240, auc:0.7876, acc:0.7062, aupr:0.7898
#
# Time taken for iteration 19: 444.4592788219452 seconds
# iteration 19 params: dim:512, length:40, num:40
# f1:0.7223, auc:0.7848, acc:0.7079, aupr:0.7880
#
# Time taken for iteration 20: 223.4564552307129 seconds
# iteration 20 params: dim:256, length:20, num:80
# f1:0.7179, auc:0.7789, acc:0.7024, aupr:0.7780
#
# Time taken for iteration 21: 223.0962529182434 seconds
# iteration 21 params: dim:256, length:80, num:40
# f1:0.7253, auc:0.7836, acc:0.7072, aupr:0.7854
#
# Time taken for iteration 22: 442.61822295188904 seconds
# iteration 22 params: dim:512, length:40, num:80
# f1:0.7319, auc:0.7843, acc:0.7144, aupr:0.7850
#
# Time taken for iteration 23: 223.95804381370544 seconds
# iteration 23 params: dim:256, length:20, num:40
# f1:0.7242, auc:0.7797, acc:0.7092, aupr:0.7863
#
# Time taken for iteration 24: 223.6224718093872 seconds
# iteration 24 params: dim:256, length:80, num:80
# f1:0.7254, auc:0.7831, acc:0.7053, aupr:0.7855
#
# Time taken for iteration 25: 438.93286204338074 seconds
# iteration 25 params: dim:512, length:80, num:20
# f1:0.7225, auc:0.7874, acc:0.7070, aupr:0.7926
#
# Time taken for iteration 26: 223.70632314682007 seconds
# iteration 26 params: dim:256, length:40, num:20
# f1:0.7281, auc:0.7845, acc:0.7140, aupr:0.7878
#
# Time taken for iteration 27: 442.0205907821655 seconds
# iteration 27 params: dim:512, length:20, num:20
# f1:0.6870, auc:0.7449, acc:0.6736, aupr:0.7567
#
# Time taken for iteration 28: 224.8853039741516 seconds
# iteration 28 params: dim:256, length:20, num:20
# f1:0.7046, auc:0.7637, acc:0.6903, aupr:0.7724
#
# Time taken for iteration 29: 443.02874183654785 seconds
# iteration 29 params: dim:512, length:40, num:20
# f1:0.7208, auc:0.7798, acc:0.7089, aupr:0.7848
#
# Time taken for iteration 30: 224.04850006103516 seconds
# iteration 30 params: dim:256, length:80, num:20
# f1:0.7291, auc:0.7855, acc:0.7117, aupr:0.7876
#
# Time taken for iteration 31: 441.22654604911804 seconds
# iteration 31 params: dim:512, length:20, num:40
# f1:0.7049, auc:0.7706, acc:0.6943, aupr:0.7767
#
# Time taken for iteration 32: 440.5810329914093 seconds
# iteration 32 params: dim:512, length:80, num:80
# f1:0.7289, auc:0.7864, acc:0.7101, aupr:0.7881
#
# Time taken for iteration 33: 234.77746295928955 seconds
# iteration 33 params: dim:256, length:40, num:80
# f1:0.7264, auc:0.7830, acc:0.7066, aupr:0.7835
#
# Time taken for iteration 34: 445.6035828590393 seconds
# iteration 34 params: dim:512, length:20, num:80
# f1:0.7199, auc:0.7741, acc:0.7028, aupr:0.7769
#
# Time taken for iteration 35: 446.2475790977478 seconds
# iteration 35 params: dim:512, length:80, num:40
# f1:0.7320, auc:0.7878, acc:0.7157, aupr:0.7917
#
# Time taken for iteration 36: 222.8687789440155 seconds
# iteration 36 params: dim:256, length:40, num:40
# f1:0.7229, auc:0.7834, acc:0.7070, aupr:0.7883
#
# Time taken for iteration 37: 120.79732894897461 seconds
# iteration 37 params: dim:128, length:80, num:10
# f1:0.7261, auc:0.7830, acc:0.7081, aupr:0.7870
